# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn import metrics
data =pd.read_csv('Market_cap.csv')
data.head()
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   years   7 non-null      int64
#  1   income  7 non-null      int64
# dtypes: int64(2)
# memory usage: 240.0 bytes

# %%
X = data[["years"]]
y = data[["income"]]

# %%
from sklearn.linear_model import LinearRegression
lin = LinearRegression()
lin.fit(X.values, y)
# Out:
# LinearRegression()

# %%
from sklearn.preprocessing import PolynomialFeatures
poly_reg = PolynomialFeatures(degree=4)
X_poly = poly_reg.fit_transform(X)
pol_reg = LinearRegression()
pol_reg.fit(X_poly, y)
# Out:
# LinearRegression()

# %%
y_pred =  pol_reg.predict(X_poly)

# %%
def visual():
    plt.scatter(X, y, color='red')
    plt.plot(X, lin.predict(X.values), color='blue')
    plt.title('Market Cap')
    plt.xlabel('Years')
    plt.ylabel('Income(Millions)')
    plt.show()
    return
visual()

# %%
def visual():
    plt.scatter(X, y, color='red')
    plt.plot(X, pol_reg.predict(poly_reg.fit_transform(X)), color='blue')
    plt.title('Market Cap')
    plt.xlabel('Years')
    plt.ylabel('Income(Millions)')
    plt.show()
    return
visual()

# %%
pol_reg.predict(poly_reg.fit_transform([[2022]]))
# Out:
# array([[7205.54159546]])

# %%
lin.predict([[2022]])
# Out:
# array([[7389.39285714]])

# %%
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error as mse
print(mse(y, y_pred)**0.5)
print(r2_score(y, y_pred))
# Out:
# 188.23506382770685
# 0.9366246404148726
